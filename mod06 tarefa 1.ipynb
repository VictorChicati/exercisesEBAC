# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
#importando as bibliotecas utilizadas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#%matplotlib notebook

# %%
df = pd.read_csv("SINASC_RO_2019.csv") # carregando o arquivo
df.columns # visualizando as colunas da base de dados
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
# Removendo a palavra "semanas" da coluna gestacao para melhorar a visualização
df['GESTACAO'] = df['GESTACAO'].str.replace('semanas', '')

# %%
fig, axs = plt.subplots(3, 2, figsize=(15, 10))

# Gráfico para APGAR1
sns.countplot(ax = axs [0, 0], x= 'APGAR1', data= df)

# Gráfico para APGAR5
sns.countplot(ax = axs [0, 1], x= 'APGAR5', data= df)

# Gráfico para Sexo
sns.countplot(ax = axs [1, 0], x= 'SEXO', data= df)

# Gráfico para Gestação
sns.countplot(ax = axs [1, 1], x= 'GESTACAO', data= df)

# Gráfico para ESTCIVMAE
sns.countplot(ax = axs [2, 0], x= 'ESTCIVMAE', data= df)

# Removendo o Gráfico não utilizado
fig.delaxes(axs[2, 1])

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
# Plotando o gráfico
sns.barplot(x='CONSULTAS', y ='APGAR5', data=df)
# Out:
# <Axes: xlabel='CONSULTAS', ylabel='APGAR5'>

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
fig, axs = plt.subplots(2, 2, figsize=(20, 10))

# Gráfico para SEXO
sns.countplot(ax = axs [0, 0], x= 'SEXO', data= df)

# Gráfico para GESTACAO
sns.countplot(ax = axs [0, 1], x= 'GESTACAO', data= df)

# Gráfico para CONSULTAS
sns.countplot(ax = axs [1, 0], x= 'CONSULTAS', data= df)

# Gráfico para ESTCIVMAE
sns.countplot(ax = axs [1, 1], x= 'ESTCIVMAE', data= df)
# Out:
# <Axes: xlabel='ESTCIVMAE', ylabel='count'>
